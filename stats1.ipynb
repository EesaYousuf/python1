# %%
# Distribution of the data 
# how to check normality of the data 
# z_test
# t_test
# chi_test
# anova_test
# f_test
data=[23,24,32,45,12,43,67,45,32,56,32]
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy=data.copy()
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
# seaborn are used for data distrubtion
import seaborn as sns
sns.distplot(data_copy)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1180\2259407773.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_copy)
# <Axes: ylabel='Density'>

# %%
sns.histplot(data_copy)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
# sortig of data
data_copy.sort()
data_copy.append(179)
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 179]

# %%
data_copy.append(210)

# %%
sns.histplot(data_copy,kde=True)
# Out:
# <Axes: ylabel='Count'>
